# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style='dark')

# %%
x = np.array([67,34,56,73,23,98,433,675,43,65,678])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
